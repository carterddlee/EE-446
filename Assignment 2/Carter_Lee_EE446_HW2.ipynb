# %% [markdown]
# # EE446 - TinyML - Assignment 2

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from tensorflow.keras import datasets, layers,models
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.keras import regularizers
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")
from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score
import c_writer
from os.path import join

# %% [markdown]
# ## Reading Data

# %%
# Reading the data and adding column header (feature) names
data = pd.read_csv("Network_anomaly_data.txt",sep=",",names=["duration","protocoltype","service",
"flag","srcbytes","dstbytes","land", "wrongfragment","urgent","hot","numfailedlogins","loggedin", "numcompromised",
"rootshell","suattempted","numroot","numfilecreations", "numshells","numaccessfiles","numoutboundcmds","ishostlogin",
"isguestlogin","count","srvcount","serrorrate", "srvserrorrate","rerrorrate","srvrerrorrate","samesrvrate",
"diffsrvrate", "srvdiffhostrate","dsthostcount","dsthostsrvcount","dsthostsamesrvrate", "dsthostdiffsrvrate",
"dsthostsamesrcportrate","dsthostsrvdiffhostrate","dsthostserrorrate","dsthostsrvserrorrate","dsthostrerrorrate",
"dsthostsrvrerrorrate","attack", "lastflag"])

# %%
data # printing the dataframe
# Out:
#         duration protocoltype   service flag  srcbytes  dstbytes  land  \
# 0              0          tcp  ftp_data   SF       491         0     0
# 1              0          udp     other   SF       146         0     0
# 2              0          tcp   private   S0         0         0     0
# 3              0          tcp      http   SF       232      8153     0
# 4              0          tcp      http   SF       199       420     0
# ...          ...          ...       ...  ...       ...       ...   ...
# 125968         0          tcp   private   S0         0         0     0
# 125969         8          udp   private   SF       105       145     0
# 125970         0          tcp      smtp   SF      2231       384     0
# 125971         0          tcp    klogin   S0         0         0     0
# 125972         0          tcp  ftp_data   SF       151         0     0
#
#         wrongfragment  urgent  hot  ...  dsthostsamesrvrate  \
# 0                   0       0    0  ...                0.17
# 1                   0       0    0  ...                0.00
# 2                   0       0    0  ...                0.10
# 3                   0       0    0  ...                1.00
# 4                   0       0    0  ...                1.00
# ...               ...     ...  ...  ...                 ...
# 125968              0       0    0  ...                0.10
# 125969              0       0    0  ...                0.96
# 125970              0       0    0  ...                0.12
# 125971              0       0    0  ...                0.03
# 125972              0       0    0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate   attack  lastflag
# 0                       0.00   normal        20
# 1                       0.00   normal        15
# 2                       0.00  neptune        19
# 3                       0.01   normal        21
# 4                       0.00   normal        21
# ...                      ...      ...       ...
# 125968                  0.00  neptune        20
# 125969                  0.00   normal        21
# 125970                  0.00   normal        18
# 125971                  0.00  neptune        20
# 125972                  0.00   normal        21
#
# [125973 rows x 43 columns]

# %% [markdown]
# ## Question 1: Data Preprocessing

# %% [markdown]
# ##### (a) Drop the 'land', 'urgent', 'numfailedlogins', 'numoutboundcmds' columns from the dataframe "data".

# %%
## INSERT YOUR CODE HERE ##
data = data.drop(columns=["land", "urgent", "numfailedlogins", "numoutboundcmds"])

# %% [markdown]
# ##### (b) Change any label that is not named normal to attack in the {'attack'} column of the dataframe data.

# %%
## INSERT YOUR CODE HERE ##
data["attack"] = data["attack"].apply(lambda x: "normal" if x == "normal" else "attack")

# %%
data #<--------- Print your modified dataframe "data"
# Out:
#         duration protocoltype   service flag  srcbytes  dstbytes  \
# 0              0          tcp  ftp_data   SF       491         0
# 1              0          udp     other   SF       146         0
# 2              0          tcp   private   S0         0         0
# 3              0          tcp      http   SF       232      8153
# 4              0          tcp      http   SF       199       420
# ...          ...          ...       ...  ...       ...       ...
# 125968         0          tcp   private   S0         0         0
# 125969         8          udp   private   SF       105       145
# 125970         0          tcp      smtp   SF      2231       384
# 125971         0          tcp    klogin   S0         0         0
# 125972         0          tcp  ftp_data   SF       151         0
#
#         wrongfragment  hot  loggedin  numcompromised  ...  dsthostsamesrvrate  \
# 0                   0    0         0               0  ...                0.17
# 1                   0    0         0               0  ...                0.00
# 2                   0    0         0               0  ...                0.10
# 3                   0    0         1               0  ...                1.00
# 4                   0    0         1               0  ...                1.00
# ...               ...  ...       ...             ...  ...                 ...
# 125968              0    0         0               0  ...                0.10
# 125969              0    0         0               0  ...                0.96
# 125970              0    0         1               0  ...                0.12
# 125971              0    0         0               0  ...                0.03
# 125972              0    0         1               0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate  attack  lastflag
# 0                       0.00  normal        20
# 1                       0.00  normal        15
# 2                       0.00  attack        19
# 3                       0.01  normal        21
# 4                       0.00  normal        21
# ...                      ...     ...       ...
# 125968                  0.00  attack        20
# 125969                  0.00  normal        21
# 125970                  0.00  normal        18
# 125971                  0.00  attack        20
# 125972                  0.00  normal        21
#
# [125973 rows x 39 columns]

# %% [markdown]
# ##### (c) Use LabelEncoder() function from the sklearn.preprocessing library to convert non-numerical attributes in the {'protocoltype', 'service', 'flag', 'attack'} columns of the dataframe data to numerical values.

# %%
## INSERT YOUR CODE HERE ##
le_protocol = LabelEncoder()
le_service = LabelEncoder()
le_flag = LabelEncoder()
le_attack = LabelEncoder()

data["protocoltype"] = le_protocol.fit_transform(data["protocoltype"])
data["service"] = le_service.fit_transform(data["service"])
data["flag"] = le_flag.fit_transform(data["flag"])
data["attack"] = le_attack.fit_transform(data["attack"])

# %%
pd.DataFrame(data) #<--------- Print your modified dataframe "data"
# Out:
#         duration  protocoltype  service  flag  srcbytes  dstbytes  \
# 0              0             1       20     9       491         0
# 1              0             2       44     9       146         0
# 2              0             1       49     5         0         0
# 3              0             1       24     9       232      8153
# 4              0             1       24     9       199       420
# ...          ...           ...      ...   ...       ...       ...
# 125968         0             1       49     5         0         0
# 125969         8             2       49     9       105       145
# 125970         0             1       54     9      2231       384
# 125971         0             1       30     5         0         0
# 125972         0             1       20     9       151         0
#
#         wrongfragment  hot  loggedin  numcompromised  ...  dsthostsamesrvrate  \
# 0                   0    0         0               0  ...                0.17
# 1                   0    0         0               0  ...                0.00
# 2                   0    0         0               0  ...                0.10
# 3                   0    0         1               0  ...                1.00
# 4                   0    0         1               0  ...                1.00
# ...               ...  ...       ...             ...  ...                 ...
# 125968              0    0         0               0  ...                0.10
# 125969              0    0         0               0  ...                0.96
# 125970              0    0         1               0  ...                0.12
# 125971              0    0         0               0  ...                0.03
# 125972              0    0         1               0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate  attack  lastflag
# 0                       0.00       1        20
# 1                       0.00       1        15
# 2                       0.00       0        19
# 3                       0.01       1        21
# 4                       0.00       1        21
# ...                      ...     ...       ...
# 125968                  0.00       0        20
# 125969                  0.00       1        21
# 125970                  0.00       1        18
# 125971                  0.00       0        20
# 125972                  0.00       1        21
#
# [125973 rows x 39 columns]

# %% [markdown]
# ## Feature Scaling and Train/Test Split

# %%
# All the features apart from Attack are what we are going to use to predict the attack status of the data
# attack = 1 (normal/not an attack) and attack = 0 (attack)
X = data.drop(['attack'],axis=1).to_numpy()

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data
X_normalized = scaler.fit_transform(X)

Y = data['attack'].to_numpy()
# Splitting X and y testing and training data
# we are taking 20% of the data for testing and 80% of the data for training
X_train, X_test, y_train, y_test = train_test_split(X_normalized, Y, test_size = 0.20)
# reshaping y test and train array
y_train = y_train.reshape(len(y_train),1)
y_test = y_test.reshape(len(y_test),1)

# %% [markdown]
# ## Question 2: Dimensionality Reduction for Visualization

# %% [markdown]
# ##### (a) Use TSNE from the sklearn.manifold library to visualize the data in the test set (X_test) in 2D. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
from sklearn.manifold import TSNE
## INSERT YOUR CODE HERE ##
tsne = TSNE(n_components=2, random_state=42, perplexity=30, learning_rate="auto", init="pca")
X_test_tsne = tsne.fit_transform(X_test)

plt.figure(figsize=(8, 6))
plt.scatter(X_test_tsne[y_test.flatten() == 0, 0], X_test_tsne[y_test.flatten() == 0, 1], c="red", s=10, label="attack")
plt.scatter(X_test_tsne[y_test.flatten() == 1, 0], X_test_tsne[y_test.flatten() == 1, 1], c="blue", s=10, label="normal")
plt.legend()
plt.title("t-SNE Visualization")
plt.show()

# %% [markdown]
# ##### (b) Use PCA from the sklearn.decomposition library to visualize the data in the test set (X_test) in 2D. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
from sklearn.decomposition import PCA
## INSERT YOUR CODE HERE ##
pca = PCA(n_components=2, random_state=42)
X_test_pca = pca.fit_transform(X_test)

plt.figure(figsize=(8, 6))
plt.scatter(X_test_pca[y_test.flatten() == 0, 0], X_test_pca[y_test.flatten() == 0, 1], c="red", s=10, label="attack")
plt.scatter(X_test_pca[y_test.flatten() == 1, 0], X_test_pca[y_test.flatten() == 1, 1], c="blue", s=10, label="normal")
plt.legend()
plt.title("PCA Visualization")
plt.show()

# %% [markdown]
# ##### (c) Use KernelPCA from the sklearn.decomposition library to visualize the data in the test set (X_test) in 2D. Use radial basis function (rbf) as the kernel. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
from sklearn.decomposition import KernelPCA
## INSERT YOUR CODE HERE ##
kpca = KernelPCA(n_components=2, kernel="rbf", random_state=42)
X_test_kpca = kpca.fit_transform(X_test)

plt.figure(figsize=(8, 6))
plt.scatter(X_test_kpca[y_test.flatten() == 0, 0], X_test_kpca[y_test.flatten() == 0, 1], c="red", s=10, label="attack")
plt.scatter(X_test_kpca[y_test.flatten() == 1, 0], X_test_kpca[y_test.flatten() == 1, 1], c="blue", s=10, label="normal")
plt.legend()
plt.title("Kernel PCA Visualization")
plt.show()

# %% [markdown]
# ## Question 3: Implementing a DNN on the dataset

# %% [markdown]
# ##### (a) Implement a deep neural network (DNN) on the Network Anomaly Dataset. Ensure to include two neurons and softmax activation in the output layer of your DNN.

# %%
# Define the DNN model
basemodel = Sequential([
    Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    Dense(32, activation="relu"),
    Dense(2, activation="softmax")
])

# %% [markdown]
# ##### (b) Compile and train your DNN model on the training set (X_train). Denote the trained model as base_model.

# %%
## INSERT YOUR CODE HERE ##
basemodel.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history = basemodel.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=20,
    batch_size=256,
    verbose=1
)
# Out:
# Epoch 1/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9689 - loss: 0.0844 - val_accuracy: 0.9928 - val_loss: 0.0233
# Epoch 2/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9945 - loss: 0.0163 - val_accuracy: 0.9944 - val_loss: 0.0140
# Epoch 3/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9962 - loss: 0.0112 - val_accuracy: 0.9962 - val_loss: 0.0114
# Epoch 4/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9967 - loss: 0.0089 - val_accuracy: 0.9968 - val_loss: 0.0086
# Epoch 5/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9972 - loss: 0.0082 - val_accuracy: 0.9969 - val_loss: 0.0079
# Epoch 6/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9972 - loss: 0.0070 - val_accuracy: 0.9966 - val_loss: 0.0084
# Epoch 7/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9978 - loss: 0.0063 - val_accuracy: 0.9976 - val_loss: 0.0072
# Epoch 8/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9975 - val_loss: 0.0068
# Epoch 9/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9982 - loss: 0.0051 - val_accuracy: 0.9982 - val_loss: 0.0066
# Epoch 10/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9982 - loss: 0.0046 - val_accuracy: 0.9975 - val_loss: 0.0078
# Epoch 11/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9985 - loss: 0.0044 - val_accuracy: 0.9989 - val_loss: 0.0055
# Epoch 12/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9987 - loss: 0.0040 - val_accuracy: 0.9978 - val_loss: 0.0056
# Epoch 13/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9987 - loss: 0.0042 - val_accuracy: 0.9981 - val_loss: 0.0057
# Epoch 14/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.9978 - val_loss: 0.0063
# Epoch 15/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9989 - loss: 0.0033 - val_accuracy: 0.9984 - val_loss: 0.0052
# Epoch 16/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9990 - loss: 0.0030 - val_accuracy: 0.9986 - val_loss: 0.0049
# Epoch 17/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.9984 - val_loss: 0.0058
# Epoch 18/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9990 - loss: 0.0028 - val_accuracy: 0.9986 - val_loss: 0.0049
# Epoch 19/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9991 - loss: 0.0027 - val_accuracy: 0.9988 - val_loss: 0.0046
# Epoch 20/20
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9991 - loss: 0.0027 - val_accuracy: 0.9984 - val_loss: 0.0057

# %% [markdown]
# ##### (c) Evaluate the base_model on the test set (X_test) using classification_report and confusion_matrix from the sklearn.metrics library. Report these numbers in your .pdf writeup file using screenshots.

# %%
## INSERT YOUR CODE HERE ##

# %%
# Save the original Keras model to HDF5 file
basemodel.save('original_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Question 4: Implementing Quantized Model

# %% [markdown]
# ##### (a) Implement Dynamic Range Quantization on the base_model. Designate the resulting quantized ML model as tflite_quant_model.

# %%
import os
# Load the trained model
base_model = tf.keras.models.load_model('original_model.h5')

## INSERT YOUR CODE HERE ##

# Load the trained model

# Representative dataset for full integer quantization
def representative_data_gen():
    for i in range(100):
        sample = X_train[i:i+1].astype(np.float32)
        yield [sample]

# Full int8 quantization
converter = tf.lite.TFLiteConverter.from_keras_model(basemodel)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_quant_model = converter.convert()

# Save the quantized TFLite model
with open("quantized_model.tflite", "wb") as f:
    f.write(tflite_quant_model)

# Compare file sizes
original_model_size = os.path.getsize("original_model.h5")
quantized_model_size = os.path.getsize("quantized_model.tflite")

print(f"Original model size: {original_model_size / 1024:.2f} KB")
print(f"Quantized model size: {quantized_model_size / 1024:.2f} KB")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved artifact at '/tmp/tmpqbijlnrb'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 38), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   138800482029008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138800482030160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138800482028816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138800482027664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138800482030736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138800482028048: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Original model size: 84.54 KB
# Quantized model size: 9.45 KB

# %%
import os

# Save the quantized model
with open('quantized_model.tflite', 'wb') as f:
    f.write(tflite_quant_model)

# Get the file sizes
original_model_size = os.path.getsize('original_model.h5')
quantized_model_size = os.path.getsize('quantized_model.tflite')

# Print the model sizes
print(f"Original model size: {original_model_size / 1024:.2f} KB")
print(f"Quantized model size: {quantized_model_size / 1024:.2f} KB")
# Out:
# Original model size: 84.54 KB
# Quantized model size: 9.45 KB

# %% [markdown]
# ##### (b) Evaluate the tflite_quant_model on the test set (X_test) using classification_report and confusion_matrix from the sklearn.metrics library. Report these numbers in your .pdf writeup file using screenshots.

# %%
## INSERT YOUR CODE HERE ##
from sklearn.metrics import classification_report, confusion_matrix

interpreter = tf.lite.Interpreter(model_path="quantizedmodel.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

input_scale, input_zero_point = input_details[0]["quantization"]
output_scale, output_zero_point = output_details[0]["quantization"]

y_pred_q = []

for i in range(len(X_test)):
    x = X_test[i:i+1].astype(np.float32)

    # Quantize input from float32 to int8
    x_quant = np.round(x / input_scale + input_zero_point).astype(np.int8)

    interpreter.set_tensor(input_details[0]["index"], x_quant)
    interpreter.invoke()

    output = interpreter.get_tensor(output_details[0]["index"])

    # Dequantize output back to float32 if desired
    output = (output.astype(np.float32) - output_zero_point) * output_scale

    y_pred_q.append(np.argmax(output, axis=1)[0])

y_pred_q = np.array(y_pred_q)

print(classification_report(y_test, y_pred_q))
print(confusion_matrix(y_test, y_pred_q))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     11758
#            1       0.99      1.00      0.99     13437
#
#     accuracy                           0.99     25195
#    macro avg       0.99      0.99      0.99     25195
# weighted avg       0.99      0.99      0.99     25195
#
# [[11606   152]
#  [   29 13408]]

# %% [markdown]
# ## Converting tflite_model to C and create the header file

# %%
# c_writer is a py file in the same folder and has been imported at the beginning of the notebook
# Reference : https://github.com/ShawnHymel/tinyml-example-anomaly-detection/blob/master/utils/c_writer.py
# We use #04x to pad the output to 2 digits with a 0x prefix
hex_array = [format(val, '#04x') for val in tflite_quant_model]
# Calling function to convert an array into a C string (requires Numpy)
# create_array(np_array, var_type, var_name, line_limit=80, indent=4)
c_model = c_writer.create_array(np.array(hex_array), 'unsigned char', "network_model")
# Calling Function to create a header file with given C code as a string
header_str = c_writer.create_header(c_model, "network_model")

# %%
#Writing to the header file
with open('network_model.h', 'w') as file:
    file.write(header_str)

# %% [markdown]
# ## Generating Samples for Inference on Arduino

# %%
# Converting a sample piece of the X test and y test data to C (for the purpose of ino code (arduino) to load and test
# the sample and compare

Xtest = X_test[5:15, :]
print(c_writer.create_array(Xtest, "float", "X_test"))
# Out:
# const unsigned int X_test_dim1 = 10;
# const unsigned int X_test_dim2 = 38;
#
# const float X_test[10][38] = {
#     0.39464518628526407, 2.219311849644404, 0.7814275260969035,
#     0.7511112872365361, -0.007737369813364, -0.004892533120637494,
#     -0.08948642202040107, -0.09507567152556495, -0.8092618187059747,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     -0.7257784945454897, -0.3681102129968653, -0.6372092679572258,
#     -0.6319290328885425, -0.37436223991967527, -0.37443160310530493,
#     0.7712831058493207, -0.349683030873482, -0.37455970440553465,
#     0.7343425609306344, -1.0356876376568842, -1.161030186584037,
#     3.901359277980255, 2.756092007079775, -0.28910340026287856,
#     -0.6395319051152512, -0.6248707997445304, -0.38763462350750655,
#     -0.3763870260680415, 0.6528228780141483, -0.11024922321249885,
#     -0.12470615670462065, 1.0873051789289023, -1.1080711219467763,
#     -0.00776224074056876, -0.004918644383724874, -0.08948642202040107,
#     -0.09507567152556495, -0.8092618187059747, -0.011663642603760032,
#     -0.036651869142258646, -0.024436507262009306, -0.01238515036740332,
#     -0.02618002418454278, -0.018609896340735923, -0.04122119759327531,
#     -0.0028174939213690777, -0.0975309439715147, -0.7257784945454897,
#     -0.3681102129968653, -0.6372092679572258, -0.6319290328885425,
#     2.7464027950834815, 2.715364578035608, 0.7712831058493207,
#     -0.349683030873482, -0.37455970440553465, 0.7343425609306344,
#     -1.0356876376568842, -1.161030186584037, 1.8899370468743355,
#     0.8790444714143312, -0.28910340026287856, -0.6395319051152512,
#     -0.6248707997445304, 1.015044370163519, 2.753913722653446,
#     -0.6563667617603728, -0.11024922321249885, -0.12470615670462065,
#     1.9437626068584992, -0.7362346401101137, -0.00776224074056876,
#     -0.004918644383724874, -0.08948642202040107, -0.09507567152556495,
#     -0.8092618187059747, -0.011663642603760032, -0.036651869142258646,
#     -0.024436507262009306, -0.01238515036740332, -0.02618002418454278,
#     -0.018609896340735923, -0.04122119759327531, -0.0028174939213690777,
#     -0.0975309439715147, 1.649598220687177, -0.12029767951855844,
#     1.602663889932865, 1.6051037177847889, -0.37436223991967527,
#     -0.37443160310530493, -1.3441748714638466, -0.07238850323553762,
#     -0.37455970440553465, 0.7343425609306344, -0.8730893919645107,
#     -1.0051099793265696, -0.17441734820805624, -0.4801968475158174,
#     -0.28910340026287856, 1.6087590765792643, 1.6189552037455606,
#     -0.38763462350750655, -0.3763870260680415, 0.21642633142264128,
#     -0.11024922321249885, -0.12470615670462065, 2.127289198557699,
#     -1.8517440856201013, -0.00776224074056876, -0.004918644383724874,
#     -0.08948642202040107, -0.09507567152556495, -0.8092618187059747,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     0.3658468341459932, -0.20290185734466074, -0.6372092679572258,
#     -0.6319290328885425, 2.7464027950834815, 2.715364578035608,
#     -1.275934291550519, -0.016929597707948767, -0.37455970440553465,
#     0.7343425609306344, -0.9272888071953019, -1.0496586099715604,
#     -0.06855302025511306, -0.4801968475158174, -0.28910340026287856,
#     -0.6395319051152512, -0.6248707997445304, 2.8744095478204597,
#     2.753913722653446, 0.21642633142264128, -0.11024922321249885,
#     -0.12470615670462065, -0.44208308523109213, 0.7511112872365361,
#     -0.00772493434976162, -0.004625949558450148, -0.08948642202040107,
#     -0.09507567152556495, 1.2356940323701657, -0.011663642603760032,
#     -0.036651869142258646, -0.024436507262009306, -0.01238515036740332,
#     -0.02618002418454278, -0.018609896340735923, -0.04122119759327531,
#     -0.0028174939213690777, -0.0975309439715147, -0.7170454919159579,
#     -0.35434285002584825, -0.6372092679572258, -0.6319290328885425,
#     -0.37436223991967527, -0.37443160310530493, 0.7712831058493207,
#     -0.349683030873482, -0.37455970440553465, -1.6848703618229999,
#     1.2587542737799418, 1.0664013456654926, -0.43907816809041417,
#     -0.25365662769412595, 0.06625202510982187, -0.6395319051152512,
#     -0.6024325397096294, -0.38763462350750655, -0.3763870260680415,
#     0.6528228780141483, -0.11024922321249885, -0.12470615670462065,
#     1.7602360151593, -0.7362346401101137, -0.00776224074056876,
#     -0.004918644383724874, -0.08948642202040107, -0.09507567152556495,
#     -0.8092618187059747, -0.011663642603760032, -0.036651869142258646,
#     -0.024436507262009306, -0.01238515036740332, -0.02618002418454278,
#     -0.018609896340735923, -0.04122119759327531, -0.0028174939213690777,
#     -0.0975309439715147, -0.1843323315145142, -0.17536713140262664,
#     1.602663889932865, 1.6051037177847889, -0.37436223991967527,
#     -0.37443160310530493, -0.9574782519549883, -0.016929597707948767,
#     -0.37455970440553465, 0.7343425609306344, -0.7285576180157343,
#     -0.8491897720691026, -0.12148518423158469, -0.4801968475158174,
#     -0.28910340026287856, 1.6087590765792643, 1.6189552037455606,
#     -0.38763462350750655, -0.3763870260680415, -0.21997021516886575,
#     -0.11024922321249885, 2.219311849644404, 1.0873051789289023,
#     0.7511112872365361, -0.007744354114839309, -0.004882337294098612,
#     -0.08948642202040107, -0.09507567152556495, -0.8092618187059747,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     -0.6821134813978305, -0.3681102129968653, -0.6372092679572258,
#     -0.6319290328885425, -0.37436223991967527, -0.37443160310530493,
#     -1.1167062717527534, 1.4804608515369513, -0.37455970440553465,
#     0.7343425609306344, 1.0961560280875682, 0.9104811384080256,
#     -0.3861460041139426, -0.4801968475158174, -0.28910340026287856,
#     -0.6395319051152512, -0.6248707997445304, -0.38763462350750655,
#     -0.3763870260680415, -0.6563667617603728, -0.11024922321249885,
#     -0.12470615670462065, 1.6990604845929, -0.7362346401101137,
#     -0.00776224074056876, -0.004918644383724874, -0.08948642202040107,
#     -0.09507567152556495, -0.8092618187059747, -0.011663642603760032,
#     -0.036651869142258646, -0.024436507262009306, -0.01238515036740332,
#     -0.02618002418454278, -0.018609896340735923, -0.04122119759327531,
#     -0.0028174939213690777, -0.0975309439715147, 1.85045728116641,
#     -0.12029767951855844, 1.602663889932865, 1.6051037177847889,
#     -0.37436223991967527, -0.37443160310530493, -1.366921731434956,
#     -0.016929597707948767, -0.37455970440553465, 0.7343425609306344,
#     -0.8730893919645107, -1.0051099793265696, -0.06855302025511306,
#     -0.4801968475158174, -0.28910340026287856, 1.6087590765792643,
#     1.6189552037455606, -0.38763462350750655, -0.3763870260680415,
#     0.21642633142264128, -0.11024922321249885, -0.12470615670462065,
#     1.0873051789289023, -0.7362346401101137, -0.00776224074056876,
#     -0.004918644383724874, -0.08948642202040107, -0.09507567152556495,
#     -0.8092618187059747, -0.011663642603760032, -0.036651869142258646,
#     -0.024436507262009306, -0.01238515036740332, -0.02618002418454278,
#     -0.018609896340735923, -0.04122119759327531, -0.0028174939213690777,
#     -0.0975309439715147, 0.5230408814775668, -0.18913449437364369,
#     1.602663889932865, 1.6051037177847889, -0.37436223991967527,
#     -0.37443160310530493, -1.275934291550519, -0.016929597707948767,
#     -0.37455970440553465, 0.7343425609306344, -0.9092223354517048,
#     -1.027384294649065, -0.06855302025511306, -0.4801968475158174,
#     -0.28910340026287856, 1.6087590765792643, 1.6189552037455606,
#     -0.38763462350750655, -0.3763870260680415, 0.6528228780141483,
#     -0.11024922321249885, -0.12470615670462065, 1.6990604845929,
#     -0.7362346401101137, -0.00776224074056876, -0.004918644383724874,
#     -0.08948642202040107, -0.09507567152556495, -0.8092618187059747,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     1.3352101260240299, -0.12029767951855844, 1.602663889932865,
#     1.6051037177847889, -0.37436223991967527, -0.37443160310530493,
#     -1.3214280114927377, -0.016929597707948767, -0.37455970440553465,
#     0.7343425609306344, -0.8730893919645107, -1.0051099793265696,
#     -0.06855302025511306, -0.4801968475158174, -0.28910340026287856,
#     1.6087590765792643, 1.6189552037455606, -0.38763462350750655,
#     -0.3763870260680415, 0.21642633142264128
# };

# %%
ytest = y_test[5:15]
print(c_writer.create_array(ytest,"uint8_t","y_test"))
# Out:
# const unsigned int y_test_dim1 = 10;
# const unsigned int y_test_dim2 = 1;
#
# const uint8_t y_test[10][1] = {
#     1, 0, 0, 0, 1, 0, 1, 0, 0, 0
# };
